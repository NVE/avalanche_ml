# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import sklearn
from sklearn.model_selection import RandomizedSearchCV
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE

from avaml.aggregatedata import ForecastDataset, LabeledData, REG_ENG, CsvMissingError

# %% [markdown]
# # Introduction
#
# We have a lot of input features and many labels. The goal of this Notebook is to see if we can trim the number of input features based on an array of different processing methods. For this Notebook, I will look at the following relationships to determine whether an input feature is relevant:
# - correlations
# - feature importances
# - feature ranking with recursive feature elimination
# - Principle Component Analysis (PCA)
#
# Another interesting thing to look at would be to see what output features (labels) we can reasonably expect a machine learning model to predict. For instance, it may be that we can only predict half of the avlanche bulletin's output fields.

# %% [markdown]
# # Read in data

# %%
model_prefix = ''
days = 1
regobs_types = list(REG_ENG.keys())
labeled_data = None
try:
    print("Reading csv")
    labeled_data = LabeledData.from_csv(days=days, regobs_types=regobs_types, with_varsom=True)
except CsvMissingError:
    print("Csv missing. Fetching online data. (This takes a long time.)")
    labeled_data = ForecastDataset(regobs_types=regobs_types).label(days=days, with_varsom=True)
    labeled_data.to_csv()
# Out:
# Reading csv

# %% [markdown]
# # Data formatting, overall distributions
#
# I go through some of these processing steps (with more printouts) in the Notebook on data distributions, so will not go through them here.

# %%
# first, drop regions
labeled_data.data = labeled_data.drop_regions().data

# then, rename indices
labeled_data.data = labeled_data.data.rename_axis(['date','region'])
labeled_data.label = labeled_data.label.rename_axis(['date', 'region'])

# flatten the hierchy of columns to 1D
labeled_data.data.columns = [' '.join(col).strip().replace(' ', '_') for col in labeled_data.data.columns.values]
labeled_data.label.columns = [' '.join(col).strip().replace(' ', '_') for col in labeled_data.label.columns.values]

# replace double underscores with single underscores
labeled_data.data.columns = [col.replace('__', '_') for col in labeled_data.data.columns.values]
labeled_data.label.columns = [col.replace('__', '_') for col in labeled_data.label.columns.values]

# convert some columns in labels to type int for averaging
labeled_data.label['CLASS_problem_amount'] = labeled_data.label['CLASS_problem_amount'].astype(int)
labeled_data.label['CLASS_danger_level'] = labeled_data.label['CLASS_danger_level'].astype(int)

for column in labeled_data.label.columns:
    if column.endswith(('_dist', '_dsize', '_lev_fill', '_prob', '_trig')):
        labeled_data.label[column] = labeled_data.label[column].astype(int)
        
# below, we can try to make categorical variables in the labels numeric
# first for the emergency warning column
warning_dict = {'Ikke gitt':0,
                'Naturlig utløste skred':1}

labeled_data.label['CLASS_emergency_warning'] = labeled_data.label['CLASS_emergency_warning'].replace(warning_dict)

# and now for the class problems
problem1 = list(np.unique(labeled_data.label.loc[:, 'CLASS_problem_1'].values))
problem2 = list(np.unique(labeled_data.label.loc[:, 'CLASS_problem_2'].values))
problem3 = list(np.unique(labeled_data.label.loc[:, 'CLASS_problem_3'].values))

list_of_problems = sorted(list(np.unique(problem1 + problem2 + problem3)))
problems_dict = {'':0, 'drift-slab':1, 'glide':2, 'new-loose':3,
                 'new-slab':4, 'pwl-slab':5, 'wet-loose':6, 'wet-slab':7}

labeled_data.label['CLASS_problem_1'] = labeled_data.label['CLASS_problem_1'].replace(problems_dict)
labeled_data.label['CLASS_problem_2'] = labeled_data.label['CLASS_problem_2'].replace(problems_dict)
labeled_data.label['CLASS_problem_3'] = labeled_data.label['CLASS_problem_3'].replace(problems_dict)

# %% [markdown]
# # Do we have redundant features that we can collapse?

# %%
for column in labeled_data.data.columns:
    if 'aspect' in column:
        print(column)
# Out:
# problem_new-loose_aspect_N_1
# problem_new-loose_aspect_NE_1
# problem_new-loose_aspect_E_1
# problem_new-loose_aspect_SE_1
# problem_new-loose_aspect_S_1
# problem_new-loose_aspect_SW_1
# problem_new-loose_aspect_W_1
# problem_new-loose_aspect_NW_1
# problem_wet-loose_aspect_N_1
# problem_wet-loose_aspect_NE_1
# problem_wet-loose_aspect_E_1
# problem_wet-loose_aspect_SE_1
# problem_wet-loose_aspect_S_1
# problem_wet-loose_aspect_SW_1
# problem_wet-loose_aspect_W_1
# problem_wet-loose_aspect_NW_1
# problem_new-slab_aspect_N_1
# problem_new-slab_aspect_NE_1
# problem_new-slab_aspect_E_1
# problem_new-slab_aspect_SE_1
# problem_new-slab_aspect_S_1
# problem_new-slab_aspect_SW_1
# problem_new-slab_aspect_W_1
# problem_new-slab_aspect_NW_1
# problem_drift-slab_aspect_N_1
# problem_drift-slab_aspect_NE_1
# problem_drift-slab_aspect_E_1
# problem_drift-slab_aspect_SE_1
# problem_drift-slab_aspect_S_1
# problem_drift-slab_aspect_SW_1
# problem_drift-slab_aspect_W_1
# problem_drift-slab_aspect_NW_1
# problem_pwl-slab_aspect_N_1
# problem_pwl-slab_aspect_NE_1
# problem_pwl-slab_aspect_E_1
# problem_pwl-slab_aspect_SE_1
# problem_pwl-slab_aspect_S_1
# problem_pwl-slab_aspect_SW_1
# problem_pwl-slab_aspect_W_1
# problem_pwl-slab_aspect_NW_1
# problem_wet-slab_aspect_N_1
# problem_wet-slab_aspect_NE_1
# problem_wet-slab_aspect_E_1
# problem_wet-slab_aspect_SE_1
# problem_wet-slab_aspect_S_1
# problem_wet-slab_aspect_SW_1
# problem_wet-slab_aspect_W_1
# problem_wet-slab_aspect_NW_1
# problem_glide_aspect_N_1
# problem_glide_aspect_NE_1
# problem_glide_aspect_E_1
# problem_glide_aspect_SE_1
# problem_glide_aspect_S_1
# problem_glide_aspect_SW_1
# problem_glide_aspect_W_1
# problem_glide_aspect_NW_1

# %%
for column in labeled_data.label.columns:
    print(labeled_data.label[column].dtypes, '     ', column)
# Out:
# int64       CLASS_danger_level
# int64       CLASS_emergency_warning
# int64       CLASS_problem_1
# int64       CLASS_problem_2
# int64       CLASS_problem_3
# int64       CLASS_problem_amount
# object       CLASS_drift-slab_cause
# int64       CLASS_drift-slab_dist
# int64       CLASS_drift-slab_dsize
# int64       CLASS_drift-slab_lev_fill
# int64       CLASS_drift-slab_prob
# int64       CLASS_drift-slab_trig
# object       CLASS_glide_cause
# int64       CLASS_glide_dist
# int64       CLASS_glide_dsize
# int64       CLASS_glide_lev_fill
# int64       CLASS_glide_prob
# int64       CLASS_glide_trig
# object       CLASS_new-loose_cause
# int64       CLASS_new-loose_dist
# int64       CLASS_new-loose_dsize
# int64       CLASS_new-loose_lev_fill
# int64       CLASS_new-loose_prob
# int64       CLASS_new-loose_trig
# object       CLASS_new-slab_cause
# int64       CLASS_new-slab_dist
# int64       CLASS_new-slab_dsize
# int64       CLASS_new-slab_lev_fill
# int64       CLASS_new-slab_prob
# int64       CLASS_new-slab_trig
# object       CLASS_pwl-slab_cause
# int64       CLASS_pwl-slab_dist
# int64       CLASS_pwl-slab_dsize
# int64       CLASS_pwl-slab_lev_fill
# int64       CLASS_pwl-slab_prob
# int64       CLASS_pwl-slab_trig
# object       CLASS_wet-loose_cause
# int64       CLASS_wet-loose_dist
# int64       CLASS_wet-loose_dsize
# int64       CLASS_wet-loose_lev_fill
# int64       CLASS_wet-loose_prob
# int64       CLASS_wet-loose_trig
# object       CLASS_wet-slab_cause
# int64       CLASS_wet-slab_dist
# int64       CLASS_wet-slab_dsize
# int64       CLASS_wet-slab_lev_fill
# int64       CLASS_wet-slab_prob
# int64       CLASS_wet-slab_trig
# object       MULTI_drift-slab_aspect
# object       MULTI_glide_aspect
# object       MULTI_new-loose_aspect
# object       MULTI_new-slab_aspect
# object       MULTI_pwl-slab_aspect
# object       MULTI_wet-loose_aspect
# object       MULTI_wet-slab_aspect
# float64       REAL_drift-slab_lev_max
# float64       REAL_drift-slab_lev_min
# float64       REAL_glide_lev_max
# float64       REAL_glide_lev_min
# float64       REAL_new-loose_lev_max
# float64       REAL_new-loose_lev_min
# float64       REAL_new-slab_lev_max
# float64       REAL_new-slab_lev_min
# float64       REAL_pwl-slab_lev_max
# float64       REAL_pwl-slab_lev_min
# float64       REAL_wet-loose_lev_max
# float64       REAL_wet-loose_lev_min
# float64       REAL_wet-slab_lev_max
# float64       REAL_wet-slab_lev_min

# %%
look_at = ['MULTI_drift-slab_aspect', 'MULTI_glide_aspect', 'MULTI_new-loose_aspect', 
           'MULTI_new-slab_aspect', 'MULTI_pwl-slab_aspect', 'MULTI_wet-loose_aspect', 
           'MULTI_wet-slab_aspect']

labeled_data.label.loc[:, look_at]
# Out:
#                   MULTI_drift-slab_aspect MULTI_glide_aspect  \
# date       region
# 2017-11-23 3031                  11100011           00000000
#            3034                  11100011           00000000
# 2017-12-02 3003                  11111111           00000000
#            3007                  00000000           00000000
#            3009                  00000000           00000000
# ...                                   ...                ...
# 2021-01-12 3031                  00000000           00000000
#            3032                  00000000           00000000
#            3034                  00000000           00000000
#            3035                  00000000           00000000
#            3037                  00000000           00000000
#
#                   MULTI_new-loose_aspect MULTI_new-slab_aspect  \
# date       region
# 2017-11-23 3031                 00000000              00000000
#            3034                 00000000              00000000
# 2017-12-02 3003                 00000000              00000000
#            3007                 00000000              00000000
#            3009                 00000000              00000000
# ...                                  ...                   ...
# 2021-01-12 3031                 00000000              00000000
#            3032                 00000000              00000000
#            3034                 00000000              00000000
#            3035                 00000000              00000000
#            3037                 00000000              00000000
#
#                   MULTI_pwl-slab_aspect MULTI_wet-loose_aspect  \
# date       region
# 2017-11-23 3031                00000000               00000000
#            3034                00000000               00000000
# 2017-12-02 3003                00000000               00000000
#            3007                11111111               00000000
#            3009                11111111               00000000
# ...                                 ...                    ...
# 2021-01-12 3031                11111111               00000000
#            3032                11111111               00000000
#            3034                11111111               00000000
#            3035                11111111               00000000
#            3037                11111111               00000000
#
#                   MULTI_wet-slab_aspect
# date       region
# 2017-11-23 3031                00000000
#            3034                00000000
# 2017-12-02 3003                00000000
#            3007                00000000
#            3009                00000000
# ...                                 ...
# 2021-01-12 3031                00000000
#            3032                00000000
#            3034                00000000
#            3035                00000000
#            3037                00000000
#
# [13115 rows x 7 columns]

# %%
for i, row in enumerate(range(labeled_data.label.loc[:, look_at].replace('00000000', np.nan).shape[0])):
    print(labeled_data.label.loc[:, look_at].replace('00000000', np.nan).iloc[i, :].values)
# Out:
# ['11100011' nan nan nan nan nan nan]
# ['11100011' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11001111' nan nan]
# [nan nan nan nan '10001111' nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11100011' nan nan nan '11111111' nan nan]
# ['11100000' nan nan nan '11111000' nan nan]
# [nan nan nan '11110001' '01111100' nan nan]
# [nan nan nan nan '01111000' nan nan]
# [nan nan nan nan '11110000' nan nan]
# [nan nan nan nan '11110000' '11111111' nan]
# [nan nan nan nan '11110000' '11111111' nan]
# ['01110000' nan nan nan '01111000' nan nan]
# ['01110000' nan nan nan '01111000' nan nan]
# [nan nan nan nan '11110000' '11111111' nan]
# ['01110000' nan nan nan nan nan nan]
# [nan nan nan nan '11111000' '11111111' nan]
# ['01110000' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11110011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11110011' nan nan]
# [nan nan nan nan '11110011' nan nan]
# ['00111100' nan nan nan nan nan nan]
# ['11111000' nan nan nan '11111111' nan nan]
# ['01111000' nan nan nan '01111100' nan nan]
# ['01111000' nan nan nan '01111100' nan nan]
# [nan nan nan nan '01111000' nan nan]
# [nan nan nan nan '01111000' nan nan]
# [nan nan nan nan '01111000' nan nan]
# [nan nan nan nan '01111000' nan nan]
# ['01110000' nan nan nan nan nan nan]
# ['01110000' nan nan nan nan nan nan]
# [nan nan nan nan '01111000' nan nan]
# ['01110000' nan nan nan nan nan nan]
# [nan nan nan nan '01111000' nan nan]
# ['01110000' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# [nan nan nan nan '11111000' nan nan]
# [nan nan nan nan '11111000' nan nan]
# [nan nan nan nan '11111000' nan nan]
# [nan nan nan nan '11111000' nan nan]
# [nan nan nan nan '11110011' nan nan]
# [nan nan nan nan '11111000' nan nan]
# ['01111100' nan nan nan nan nan nan]
# ['11111000' nan nan nan '11111111' nan nan]
# ['01111000' nan nan nan '01111100' nan nan]
# ['01111000' nan nan nan '01111100' nan nan]
# [nan nan nan nan '01111000' nan nan]
# [nan nan nan nan '01111000' nan nan]
# [nan nan nan nan '01111000' nan nan]
# [nan nan nan nan '01111000' nan nan]
# ['01110000' nan nan nan nan nan nan]
# ['01110000' nan nan nan nan nan nan]
# [nan nan nan nan '01111000' nan nan]
# ['01110000' nan nan nan nan nan nan]
# [nan nan nan nan '01111000' nan nan]
# ['01111000' nan nan nan nan nan nan]
# ['10001111' nan nan nan nan nan nan]
# [nan nan nan nan '01111100' nan nan]
# [nan nan nan nan '11111000' nan nan]
# ['11111000' nan nan nan '11111001' nan nan]
# ['11111000' nan nan nan '11111111' nan nan]
# [nan nan nan '01111100' '11110011' nan nan]
# ['01111100' nan nan nan '11111000' nan nan]
# ['01111100' nan nan nan nan nan nan]
# ['11111000' nan nan nan '11111111' nan nan]
# ['11111000' nan nan nan '11111000' nan nan]
# ['11111000' nan nan nan '01111100' nan nan]
# [nan nan nan '01111000' '01111000' '11111111' nan]
# [nan nan nan '11111000' '01111000' '11111111' nan]
# [nan nan nan '01111000' nan '11111111' '01111000']
# [nan nan nan '01111000' nan '11111111' '11111000']
# [nan nan nan '01110000' nan nan '11111111']
# [nan nan nan '01110000' nan nan '11111111']
# [nan nan nan nan '11111111' '11111111' '11111000']
# [nan nan nan '01110000' nan nan '11111111']
# [nan nan nan '11111000' nan '11111111' '11111000']
# [nan nan nan '01110000' nan nan '11111111']
# ['10001111' nan nan nan nan nan nan]
# [nan nan nan '11111000' '11111000' nan nan]
# [nan nan nan '11111000' '11111000' nan nan]
# ['11111000' nan nan nan '11111000' nan nan]
# ['11111000' nan nan nan '11111111' nan nan]
# ['01111100' nan nan nan '11110011' nan nan]
# ['01111100' nan nan nan '11111000' nan nan]
# ['01111100' nan nan nan nan nan nan]
# ['11111000' nan nan nan '11111111' nan nan]
# ['11111000' nan nan nan '11111000' nan nan]
# ['11111000' nan nan nan '01111100' nan nan]
# [nan nan '11111111' '01111000' nan nan nan]
# [nan nan nan '01111000' nan '11111111' '01111000']
# [nan nan nan nan nan '11111111' '01111000']
# [nan nan nan nan nan '11111111' '11111000']
# [nan nan nan '11100000' nan nan '11111111']
# [nan nan nan '11100000' nan nan '11111111']
# [nan nan nan nan nan '11111111' '11111000']
# [nan nan nan '11100000' nan nan '11111111']
# [nan nan nan nan nan '11111111' '11111000']
# [nan nan nan '11100000' nan nan '11111111']
# ['10001111' nan nan nan nan nan nan]
# ['11111000' nan nan nan '11111111' nan nan]
# ['11111000' nan nan nan '11111111' nan nan]
# ['11111111' nan nan nan '11111111' nan nan]
# ['11111111' nan nan nan '11111111' nan nan]
# ['10001111' nan nan nan '11110011' nan nan]
# ['11000111' nan nan nan '11111000' nan nan]
# ['01111100' nan nan nan nan nan nan]
# ['10001111' nan nan nan '11111111' nan nan]
# ['10001111' nan nan nan '11111000' nan nan]
# 
11001111' nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan '11111111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['10000011' nan nan nan '11111111' nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan '11000111' nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['10000011' nan nan nan '11111111' nan nan]
# [nan nan nan '11000011' nan nan '11111111']
# [nan nan nan nan '11001111' nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan '11111111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['10000011' nan nan nan '11111111' nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan '11000111' nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['10000011' nan nan nan '11111111' nan nan]
# [nan nan nan '11000011' nan nan nan]
# ['11000111' nan nan nan '11001111' nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan '11111111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['10000111' nan nan nan '11111111' nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['10000111' nan nan nan '11111111' nan nan]
# [nan nan nan '11000011' nan nan nan]
# [nan nan nan '11000111' '11001111' nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# [nan nan nan nan '10001111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['10001111' nan nan nan '11111111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['10001111' nan nan nan '11000111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['00011111' nan nan nan '11111111' nan nan]
# ['11000011' nan nan nan nan nan nan]
# [nan nan nan '11000111' '11001111' nan nan]
# ['11000011' nan nan nan nan nan nan]
# [nan nan nan nan '11000111' nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# [nan nan nan nan '10001111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['10001111' nan nan nan '11111111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['10001111' nan nan nan '11111111' nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['00011111' nan nan nan '11111111' nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan '11001111' nan nan]
# ['11000011' nan nan nan nan nan nan]
# [nan nan nan nan '11000111' nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# [nan nan nan nan '10001111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# [nan nan nan nan '10001111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# [nan nan nan nan '10001111' nan nan]
# ['10000011' nan nan nan nan nan nan]
# [nan nan nan '00011100' nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['10001111' nan nan nan '11111111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['10001111' nan nan nan '11000111' nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['00011111' nan nan nan '11111111' nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['11000111' nan nan nan '11001111' nan nan]
# ['11000011' nan nan nan nan nan nan]
# [nan nan nan nan '11100111' nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# [nan nan nan nan '10001111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# [nan nan nan nan '10001111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# [nan nan nan nan '10001111' nan nan]
# [nan nan nan '10001111' nan nan nan]
# ['00011111' nan nan nan nan nan nan]
# [nan nan nan '10000011' nan nan nan]
# [nan nan nan '00000111' nan nan nan]
# ['11000111' nan nan nan '11111111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['10001111' nan nan nan '11000111' nan nan]
# ['10000111' nan nan nan nan nan nan]
# [nan nan nan nan '11111111' nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['11110001' nan nan nan '11111111' nan nan]
# ['11000011' nan nan nan nan nan nan]
# [nan nan nan nan '11100111' nan nan]
# [nan nan nan nan '11000011' nan nan]
# ['11100001' nan nan nan nan nan nan]
# ['11100001' nan nan nan nan nan nan]
# ['11100001' nan nan nan nan nan nan]
# [nan nan nan nan '10001111' nan nan]
# ['11110001' nan nan nan nan nan nan]
# [nan nan nan nan '10001111' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan '11111111' nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# [nan nan nan '11111111' nan nan nan]
# [nan nan nan '11111111' nan nan nan]
# ['11000111' nan nan nan '11111111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['10000011' nan nan nan nan nan nan]
# ['10001111' nan nan nan '11111111' nan nan]
# ['11111111' nan nan nan '10000001' nan nan]
# [nan nan nan nan '11111111' nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['11111111' nan nan nan '11111111' nan nan]
# ['11000011' nan nan nan nan nan nan]
# ['11100001' nan nan nan '11100111' nan nan]
# [nan nan nan nan '11000011' nan nan]
# [nan nan nan nan '11100001' nan nan]
# [nan nan nan nan '11100001' nan nan]
# [nan nan nan nan '11100001' nan nan]
# [nan nan nan nan '10001111' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '10001111' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11111111' nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# [nan nan nan '11111111' nan nan nan]
# [nan nan nan '11111111' nan nan nan]
# ['11000111' nan nan nan '11111111' nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# [nan nan nan nan '11111111' nan nan]
# ['11111111' nan nan nan '10000001' nan nan]
# [nan nan nan nan '11111111' nan nan]
# ['10000111' nan nan nan nan nan nan]
# ['11111111' nan nan nan '11111111' nan nan]
# [nan nan nan nan nan nan '11111111']
# ['11100001' nan nan nan '11100111' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100001' nan '11111111']
# [nan nan nan nan '11100001' nan '11111111']
# [nan nan nan nan '11100001' nan '11111111']
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11111000' nan nan]
# [nan nan nan nan '11111111' nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# [nan nan nan '11111111' nan nan nan]
# [nan nan nan '11111111' nan nan nan]
# ['11000111' nan nan nan '11111111' nan nan]
# [nan nan '11111111' nan nan nan nan]
# ['10001111' nan nan nan nan nan nan]
# [nan nan nan nan '11111111' nan nan]
# ['10001111' nan nan nan '10000001' nan nan]
# [nan nan nan nan '11111111' nan nan]
# ['10001111' nan nan nan nan nan nan]
# ['11111111' nan nan nan '11111111' nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11100001' nan nan nan '11100111' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100001' nan nan]
# [nan nan nan nan '11100001' nan nan]
# [nan nan nan nan '11100001' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11111000' nan nan]
# [nan nan nan nan '11000111' nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11100111' nan nan nan nan nan nan]
# ['11000111' nan nan nan '11111111' nan nan]
# [nan nan '11111111' nan nan nan nan]
# ['10001111' nan nan nan '10000001' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '10001111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# ['10001111' nan nan nan nan nan nan]
# ['11000111' nan nan nan '11111111' nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11100011' nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100001' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11111000' nan nan]
# [nan nan nan nan '11000111' nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11000111' nan nan nan nan nan nan]
# ['11100111' nan nan nan nan nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan '11111111' nan nan nan nan]
# ['10001111' nan nan nan '10000001' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '10001111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# ['10001111' nan nan nan nan nan nan]
# ['11110001' nan nan nan '11111111' nan nan]
# ['11100011' nan nan nan nan nan nan]
# ['11100011' nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100001' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11111000' nan nan]
# [nan nan nan nan '11000111' nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11111111' nan nan nan nan nan nan]
# ['11111111' nan '11111111' nan nan nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# ['10001111' nan nan nan '10000001' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '10001111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# ['10001111' nan nan nan nan nan nan]
# ['11100011' nan nan nan '11111111' nan nan]
# ['11100011' nan nan nan nan nan nan]
# ['11100011' nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100001' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11111000' nan nan]
# [nan nan nan nan '11000111' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11111001' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11110001' nan nan]
# ['10001111' nan nan nan '11111111' nan nan]
# ['11100011' nan nan nan nan nan nan]
# ['11100011' nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100001' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11000111' nan nan]
# [nan nan nan nan '11111001' nan nan]
# [nan nan nan nan '11111001' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11111001' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11111001' nan nan]
# [nan nan nan nan '11111001' nan nan]
# [nan nan nan nan '11111001' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111001' nan nan]
# ['10001111' nan nan nan '11111111' nan nan]
# ['11100011' nan nan nan nan nan nan]
# ['11111111' nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100001' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11000111' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11111001' nan nan]
# [nan nan nan nan '11111001' nan nan]
# [nan nan nan nan '11111001' nan nan]
# [nan nan nan nan '11111001' nan nan]
# [nan nan nan nan '11111001' nan nan]
# [nan nan nan nan '11111001' nan nan]
# [nan nan nan nan '11111001' nan nan]
# [nan nan nan nan '11111001' nan nan]
# ['10001111' nan nan nan '11111111' nan nan]
# ['11100011' nan nan nan nan nan nan]
# ['11111111' nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11100001' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11110001' nan nan]
# [nan nan nan nan '11100011' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11000111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111111' nan nan]
# [nan nan nan nan '11111111' nan nan]

# %% [markdown]
# **I wonder if it isn't better to have these `cause` columns combined into one.**
#
# **Same with the wind or `aspect` columns. Then we could groupby what the cause was to then analyze aspect or something like that. Or, like above, it only looks like each column is represented once. So I could take the only available value, and then split that into 8 new columns representing each direction, and fill with the available value. And then drop these MULTI columns.**
#
# **Actually, same with the avalanche problems?**

# %% [markdown]
# # Correlation analysis

# %%
features_and_labels = features = pd.concat([labeled_data.data, labeled_data.label], axis=1)
features_and_labels.shape
# Out:
# (13115, 314)

# %%
# drop columns that include text, create correlations matrix
only_numeric = features_and_labels.select_dtypes(include='number')
correlations = only_numeric.corr()

# shorten the x axis to only the labels
keep_cols = [col for col in labeled_data.label if col in correlations.columns]
drop_rows = list(set(correlations.columns) - set(keep_cols))
correlations = correlations.loc[drop_rows, keep_cols]

# there are some rows with only nan values, we can drop those here
empty_rows = [item for item in correlations.index if correlations.loc[item].isna().all() == True]
correlations.drop(empty_rows, inplace = True)

# %%
print(correlations.shape)
# Out:
# (165, 55)

# %% [markdown]
# **That is a lot of columns, still. Another thing to try would be to drop all rows where the absolute value of the correlation is below 0.25 or 0.25, for all values. These input features probably don't need to be considered.**

# %%
weak_correlations = [(abs(correlations.loc[idx, :].values) < 0.25).all() for idx in correlations.index]
correlations.loc[weak_correlations, :]
# Out:
#                                  CLASS_danger_level  CLASS_emergency_warning  \
# wind_chg_start_12_0                        0.127779                 0.056323
# wind_dir_N_0                              -0.035648                -0.048012
# precip_most_exposed_0                      0.006142                 0.002346
# wind_dir_SE_0                             -0.174427                -0.092408
# wind_chg_start_18_0                        0.117878                 0.039247
# problem_new-loose_lev_fill_4_1            -0.004446                -0.009574
# temp_fl_start_0_0                         -0.024942                -0.011614
# problem_new-loose_lev_fill_2_1             0.024787                -0.011548
# wind_chg_dir_SE_0                          0.015820                -0.030780
# wind_chg_dir_SW_0                          0.137233                 0.100253
# wind_chg_dir_S_0                           0.028854                -0.020837
# wind_chg_start_0_0                         0.037859                 0.020968
# wind_dir_S_0                              -0.072425                -0.024265
# wind_dir_E_0                              -0.064153                -0.065905
# wind_chg_dir_W_0                           0.135825                 0.088633
# wind_chg_dir_NW_0                          0.103763                 0.063405
# temp_fl_start_6_0                          0.066676                 0.019519
# problem_new-slab_lev_fill_4_1              0.010713                -0.002885
# problem_wet-slab_lev_fill_2_1              0.165316                 0.128492
# wind_chg_dir_N_0                           0.043717                 0.004366
# wind_dir_SW_0                              0.088017                 0.080403
# precip_0                                   0.001479                -0.001473
# problem_wet-loose_lev_fill_3_1            -0.037891                -0.008163
# problem_pwl-slab_lev_fill_3_1             -0.001340                -0.002885
# wind_dir_NW_0                              0.039033                -0.014240
# problem_new-slab_lev_fill_2_1              0.004638                -0.004998
# temp_fl_start_12_0                         0.069564                 0.003476
# wind_dir_W_0                               0.194684                 0.146047
# problem_pwl-slab_lev_fill_2_1              0.015460                -0.017940
# temp_fl_start_18_0                        -0.028266                 0.025599
# problem_drift-slab_lev_fill_4_1            0.002095                 0.019883
# wind_chg_dir_E_0                           0.006003                -0.028183
# wind_chg_dir_NE_0                          0.031747                -0.011310
# wind_dir_NE_0                             -0.054276                -0.054734
# problem_glide_lev_fill_3_1                -0.001340                -0.002885
# wind_chg_start_6_0                         0.101921                 0.035072
#
#                                  CLASS_problem_1  CLASS_problem_2  \
# wind_chg_start_12_0                    -0.058495         0.039847
# wind_dir_N_0                            0.005104        -0.043055
# precip_most_exposed_0                   0.000215         0.017305
# wind_dir_SE_0                          -0.072229        -0.091066
# wind_chg_start_18_0                    -0.068729         0.034206
# problem_new-loose_lev_fill_4_1         -0.012899        -0.009626
# temp_fl_start_0_0                      -0.056879        -0.012860
# problem_new-loose_lev_fill_2_1         -0.015028         0.000360
# wind_chg_dir_SE_0                      -0.090891        -0.018517
# wind_chg_dir_SW_0                       0.015269         0.086503
# wind_chg_dir_S_0                       -0.024049         0.026867
# wind_chg_start_0_0                      0.005663         0.002809
# wind_dir_S_0                           -0.024947        -0.034335
# wind_dir_E_0                           -0.010206        -0.051797
# wind_chg_dir_W_0                       -0.012112         0.058057
# wind_chg_dir_NW_0                      -0.073983         0.003275
# temp_fl_start_6_0                      -0.069341        -0.019632
# problem_new-slab_lev_fill_4_1          -0.008138         0.009370
# problem_wet-slab_lev_fill_2_1          -0.028711         0.086930
# wind_chg_dir_N_0                       -0.043111        -0.020398
# wind_dir_SW_0                           0.059924         0.082377
# precip_0                                0.000769         0.015982
# problem_wet-loose_lev_fill_3_1          0.032096        -0.011679
# problem_pwl-slab_lev_fill_3_1          -0.008138         0.009370
# wind_dir_NW_0                          -0.003495        -0.010628
# problem_new-slab_lev_fill_2_1           0.019651         0.004540
# temp_fl_start_12_0                      0.031082         0.064363
# wind_dir_W_0                            0.027861         0.106755
# problem_pwl-slab_lev_fill_2_1          -0.012439         0.038643
# temp_fl_start_18_0                      0.127585         0.024893
# problem_drift-slab_lev_fill_4_1        -0.024215        -0.001863
# wind_chg_dir_E_0                       -0.055363        -0.036508
# wind_chg_dir_NE_0                      -0.021091        -0.013860
# wind_dir_NE_0                           0.011490        -0.013909
# problem_glide_lev_fill_3_1             -0.008138         0.012745
# wind_chg_start_6_0                     -0.067235         0.007832
#
#                                  CLASS_problem_3  CLASS_problem_amount  \
# wind_chg_start_12_0                     0.013484              0.039988
# wind_dir_N_0                           -0.026083             -0.031699
# precip_most_exposed_0                   0.004648              0.027602
# wind_dir_SE_0                          -0.056061             -0.108283
# wind_chg_start_18_0                     0.016747              0.036723
# problem_new-loose_lev_fill_4_1         -0.006008             -0.010156
# temp_fl_start_0_0                      -0.032561             -0.031858
# problem_new-loose_lev_fill_2_1         -0.007247              0.002910
# wind_chg_dir_SE_0                      -0.014390             -0.018484
# wind_chg_dir_SW_0                       0.041441              0.075343
# wind_chg_dir_S_0                        0.002981              0.028264
# wind_chg_start_0_0                     -0.013699             -0.007244
# wind_dir_S_0                           -0.012735             -0.036639
# wind_dir_E_0                           -0.026484             -0.049614
# wind_chg_dir_W_0                        0.042374              0.073953
# wind_chg_dir_NW_0                      -0.004977             -0.004504
# temp_fl_start_6_0                      -0.011695             -0.028376
# problem_new-slab_lev_fill_4_1          -0.001811              0.006162
# problem_wet-slab_lev_fill_2_1           0.074779              0.074811
# wind_chg_dir_N_0                       -0.008693             -0.018899
# wind_dir_SW_0                           0.066265              0.085602
# precip_0                                0.003523              0.026338
# problem_wet-loose_lev_fill_3_1         -0.005123             -0.003069
# problem_pwl-slab_lev_fill_3_1          -0.001811              0.006162
# wind_dir_NW_0                          -0.027042             -0.013244
# problem_new-slab_lev_fill_2_1           0.044638              0.027410
# temp_fl_start_12_0                      0.019249              0.073566
# wind_dir_W_0                            0.066535              0.108630
# problem_pwl-slab_lev_fill_2_1          -0.013699              0.040849
# temp_fl_start_18_0                      0.046183              0.047431
# problem_drift-slab_lev_fill_4_1        -0.008103             -0.004854
# wind_chg_dir_E_0                       -0.006128             -0.026757
# wind_chg_dir_NE_0                      -0.010361             -0.010616
# wind_dir_NE_0                          -0.019023              0.002129
# problem_glide_lev_fill_3_1             -0.001811              0.006162
# wind_chg_start_6_0                      0.003795              0.009328
#
#                                  CLASS_drift-slab_dist  \
# wind_chg_start_12_0                           0.085113
# wind_dir_N_0                                 -0.007495
# precip_most_exposed_0                        -0.001198
# wind_dir_SE_0                                 0.003173
# wind_chg_start_18_0                           0.093398
# problem_new-loose_lev_fill_4_1                0.002801
# temp_fl_start_0_0                             0.033307
# problem_new-loose_lev_fill_2_1                0.021098
# wind_chg_dir_SE_0                             0.073241
# wind_chg_dir_SW_0                             0.042724
# wind_chg_dir_S_0                              0.034953
# wind_chg_start_0_0                            0.015262
# wind_dir_S_0                                 -0.018133
# wind_dir_E_0                                 -0.015718
# wind_chg_dir_W_0                              0.061085
# wind_chg_dir_NW_0                             0.069076
# temp_fl_start_6_0                             0.056793
# problem_new-slab_lev_fill_4_1                 0.016763
# problem_wet-slab_lev_fill_2_1                 0.093697
# wind_chg_dir_N_0                              0.043040
# wind_dir_SW_0                                -0.011128
# precip_0                                     -0.002545
# problem_wet-loose_lev_fill_3_1               -0.026886
# problem_pwl-slab_lev_fill_3_1                 0.008008
# wind_dir_NW_0                                 0.000725
# problem_new-slab_lev_fill_2_1                -0.006350
# temp_fl_start_12_0                            0.007374
# wind_dir_W_0                                  0.037713
# problem_pwl-slab_lev_fill_2_1                 0.024559
# temp_fl_start_18_0                           -0.082394
# problem_drift-slab_lev_fill_4_1               0.028001
# wind_chg_dir_E_0                              0.056450
# wind_chg_dir_NE_0                             0.036112
# wind_dir_NE_0                                -0.015044
# problem_glide_lev_fill_3_1                    0.008008
# wind_chg_start_6_0                            0.097501
#
#                                  CLASS_drift-slab_dsize  \
# wind_chg_start_12_0                            0.073632
# wind_dir_N_0                                  -0.012426
# precip_most_exposed_0                         -0.002871
# wind_dir_SE_0                                 -0.001952
# wind_chg_start_18_0                            0.089012
# problem_new-loose_lev_fill_4_1                 0.007198
# temp_fl_start_0_0                              0.040245
# problem_new-loose_lev_fill_2_1                 0.005370
# wind_chg_dir_SE_0                              0.069076
# wind_chg_dir_SW_0                              0.038869
# wind_chg_dir_S_0                               0.018798
# wind_chg_start_0_0                            -0.006064
# wind_dir_S_0                                  -0.017098
# wind_dir_E_0                                  -0.017201
# wind_chg_dir_W_0                               0.060763
# wind_chg_dir_NW_0                              0.068216
# temp_fl_start_6_0                              0.061492
# problem_new-slab_lev_fill_4_1                  0.005654
# problem_wet-slab_lev_fill_2_1                  0.095871
# wind_chg_dir_N_0                               0.037774
# wind_dir_SW_0                                 -0.005640
# precip_0                                      -0.004334
# problem_wet-loose_lev_fill_3_1                -0.027378
# problem_pwl-slab_lev_fill_3_1                  0.005654
# wind_dir_NW_0                                 -0.001394
# problem_new-slab_lev_fill_2_1                 -0.007911
# temp_fl_start_12_0                            -0.006657
# wind_dir_W_0                                   0.042076
# problem_pwl-slab_lev_fill_2_1                  0.024460
# temp_fl_start_18_0                            -0.081871
# problem_drift-slab_lev_fill_4_1                0.021871
# wind_chg_dir_E_0                               0.048752
# wind_chg_dir_NE_0                              0.020396
# wind_dir_NE_0                                 -0.014682
# problem_glide_lev_fill_3_1                     0.005654
# wind_chg_start_6_0                             0.087860
#
#                                  CLASS_drift-slab_lev_fill  \
# wind_chg_start_12_0                               0.053742
# wind_dir_N_0                                     -0.011377
# precip_most_exposed_0                             0.004277
# wind_dir_SE_0                                     0.050834
# wind_chg_start_18_0                               0.067965
# problem_new-loose_lev_fill_4_1                    0.002560
# temp_fl_start_0_0                                 0.026850
# problem_new-loose_lev_fill_2_1                    0.006594
# wind_chg_dir_SE_0                                 0.079070
# wind_chg_dir_SW_0                                 0.012387
# wind_chg_dir_S_0                                  0.028032
# wind_chg_start_0_0                               -0.006148
# wind_dir_S_0                                      0.027317
# wind_dir_E_0                                     -0.010550
# wind_chg_dir_W_0                                  0.030827
# wind_chg_dir_NW_0                                 0.036757
# temp_fl_start_6_0                                 0.042119
# problem_new-slab_lev_fill_4_1                     0.007000
# problem_wet-slab_lev_fill_2_1                     0.050728
# wind_chg_dir_N_0                                  0.026694
# wind_dir_SW_0                                    -0.017090
# precip_0                                          0.003903
# problem_wet-loose_lev_fill_3_1                   -0.028652
# problem_pwl-slab_lev_fill_3_1                     0.007000
# wind_dir_NW_0                                    -0.028851
# problem_new-slab_lev_fill_2_1                    -0.007653
# temp_fl_start_12_0                               -0.010144
# wind_dir_W_0                                     -0.007864
# problem_pwl-slab_lev_fill_2_1                     0.023405
# temp_fl_start_18_0                               -0.082234
# problem_drift-slab_lev_fill_4_1                   0.081148
# wind_chg_dir_E_0                                  0.049722
# wind_chg_dir_NE_0                                 0.016480
# wind_dir_NE_0                                    -0.006348
# problem_glide_lev_fill_3_1                        0.007000
# wind_chg_start_6_0                                0.067334
#
#                                  CLASS_drift-slab_prob  ...  \
# wind_chg_start_12_0                           0.066868  ...
# wind_dir_N_0                                 -0.012304  ...
# precip_most_exposed_0                         0.005197  ...
# wind_dir_SE_0                                 0.044159  ...
# wind_chg_start_18_0                           0.074987  ...
# problem_new-loose_lev_fill_4_1                0.002164  ...
# temp_fl_start_0_0                             0.029463  ...
# problem_new-loose_lev_fill_2_1                0.006132  ...
# wind_chg_dir_SE_0                             0.075591  ...
# wind_chg_dir_SW_0                             0.019020  ...
# wind_chg_dir_S_0                              0.026075  ...
# wind_chg_start_0_0                           -0.007868  ...
# wind_dir_S_0                                  0.016684  ...
# wind_dir_E_0                                 -0.011876  ...
# wind_chg_dir_W_0                              0.042343  ...
# wind_chg_dir_NW_0                             0.051591  ...
# temp_fl_start_6_0                             0.046222  ...
# problem_new-slab_lev_fill_4_1                 0.006909  ...
# problem_wet-slab_lev_fill_2_1                 0.060690  ...
# wind_chg_dir_N_0                              0.036769  ...
# wind_dir_SW_0                                -0.020408  ...
# precip_0                                      0.004391  ...
# problem_wet-loose_lev_fill_3_1               -0.029132  ...
# problem_pwl-slab_lev_fill_3_1                 0.006909  ...
# wind_dir_NW_0                                -0.020339  ...
# problem_new-slab_lev_fill_2_1                -0.007902  ...
# temp_fl_start_12_0                           -0.010811  ...
# wind_dir_W_0                                  0.002705  ...
# problem_pwl-slab_lev_fill_2_1                 0.028674  ...
# temp_fl_start_18_0                           -0.085918  ...
# problem_drift-slab_lev_fill_4_1               0.023220  ...
# wind_chg_dir_E_0                              0.050602  ...
# wind_chg_dir_NE_0                             0.014575  ...
# wind_dir_NE_0                                -0.008966  ...
# problem_glide_lev_fill_3_1                    0.006909  ...
# wind_chg_start_6_0                            0.071062  ...
#
#                                  REAL_new-loose_lev_max  \
# wind_chg_start_12_0                           -0.004016
# wind_dir_N_0                                   0.007589
# precip_most_exposed_0                         -0.003178
# wind_dir_SE_0                                 -0.035617
# wind_chg_start_18_0                            0.014822
# problem_new-loose_lev_fill_4_1                 0.063921
# temp_fl_start_0_0                             -0.030035
# problem_new-loose_lev_fill_2_1                 0.208307
# wind_chg_dir_SE_0                             -0.004865
# wind_chg_dir_SW_0                             -0.017362
# wind_chg_dir_S_0                              -0.018052
# wind_chg_start_0_0                            -0.005894
# wind_dir_S_0                                  -0.011072
# wind_dir_E_0                                  -0.011072
# wind_chg_dir_W_0                              -0.007851
# wind_chg_dir_NW_0                              0.028433
# temp_fl_start_6_0                              0.007025
# problem_new-slab_lev_fill_4_1                 -0.000779
# problem_wet-slab_lev_fill_2_1                 -0.014255
# wind_chg_dir_N_0                               0.026236
# wind_dir_SW_0                                 -0.031608
# precip_0                                      -0.003492
# problem_wet-loose_lev_fill_3_1                -0.002204
# problem_pwl-slab_lev_fill_3_1                 -0.000779
# wind_dir_NW_0                                  0.076662
# problem_new-slab_lev_fill_2_1                 -0.001349
# temp_fl_start_12_0                             0.019662
# wind_dir_W_0                                   0.021974
# problem_pwl-slab_lev_fill_2_1                 -0.005894
# temp_fl_start_18_0                             0.010352
# problem_drift-slab_lev_fill_4_1               -0.003486
# wind_chg_dir_E_0                              -0.013295
# wind_chg_dir_NE_0                             -0.010237
# wind_dir_NE_0                                 -0.015394
# problem_glide_lev_fill_3_1                    -0.000779
# wind_chg_start_6_0                            -0.018338
#
#                                  REAL_new-loose_lev_min  \
# wind_chg_start_12_0                           -0.012093
# wind_dir_N_0                                   0.005120
# precip_most_exposed_0                         -0.002036
# wind_dir_SE_0                                 -0.040110
# wind_chg_start_18_0                            0.000127
# problem_new-loose_lev_fill_4_1                 0.095178
# temp_fl_start_0_0                             -0.028279
# problem_new-loose_lev_fill_2_1                 0.019963
# wind_chg_dir_SE_0                             -0.020758
# wind_chg_dir_SW_0                             -0.018191
# wind_chg_dir_S_0                              -0.015950
# wind_chg_start_0_0                            -0.004585
# wind_dir_S_0                                  -0.008614
# wind_dir_E_0                                  -0.012434
# wind_chg_dir_W_0                               0.003900
# wind_chg_dir_NW_0                              0.022532
# temp_fl_start_6_0                             -0.015592
# problem_new-slab_lev_fill_4_1                 -0.000606
# problem_wet-slab_lev_fill_2_1                 -0.013335
# wind_chg_dir_N_0                               0.010853
# wind_dir_SW_0                                 -0.034959
# precip_0                                      -0.002533
# problem_wet-loose_lev_fill_3_1                -0.001715
# problem_pwl-slab_lev_fill_3_1                 -0.000606
# wind_dir_NW_0                                  0.052058
# problem_new-slab_lev_fill_2_1                 -0.001050
# temp_fl_start_12_0                             0.029394
# wind_dir_W_0                                   0.049850
# problem_pwl-slab_lev_fill_2_1                 -0.004585
# temp_fl_start_18_0                             0.013075
# problem_drift-slab_lev_fill_4_1               -0.002712
# wind_chg_dir_E_0                              -0.010343
# wind_chg_dir_NE_0                             -0.009772
# wind_dir_NE_0                                 -0.010457
# problem_glide_lev_fill_3_1                    -0.000606
# wind_chg_start_6_0                            -0.017128
#
#                                  REAL_new-slab_lev_max  REAL_new-slab_lev_min  \
# wind_chg_start_12_0                           0.031845              -0.006366
# wind_dir_N_0                                  0.002129              -0.005687
# precip_most_exposed_0                        -0.008727              -0.004366
# wind_dir_SE_0                                -0.096474              -0.063001
# wind_chg_start_18_0                           0.035245              -0.001929
# problem_new-loose_lev_fill_4_1                0.022725              -0.006082
# temp_fl_start_0_0                            -0.026901              -0.015174
# problem_new-loose_lev_fill_2_1                0.021861              -0.007336
# wind_chg_dir_SE_0                            -0.010877               0.011033
# wind_chg_dir_SW_0                             0.006610              -0.009114
# wind_chg_dir_S_0                              0.013535              -0.005162
# wind_chg_start_0_0                            0.009880               0.001143
# wind_dir_S_0                                  0.004388               0.041261
# wind_dir_E_0                                 -0.016147               0.004403
# wind_chg_dir_W_0                              0.053648               0.000301
# wind_chg_dir_NW_0                             0.039650               0.009075
# temp_fl_start_6_0                             0.018939               0.015142
# problem_new-slab_lev_fill_4_1                -0.003372              -0.001833
# problem_wet-slab_lev_fill_2_1                 0.024796               0.018789
# wind_chg_dir_N_0                              0.020266              -0.005266
# wind_dir_SW_0                                 0.024776              -0.001435
# precip_0                                     -0.010946              -0.005994
# problem_wet-loose_lev_fill_3_1               -0.009539              -0.005186
# problem_pwl-slab_lev_fill_3_1                -0.003372              -0.001833
# wind_dir_NW_0                                 0.042553               0.024126
# problem_new-slab_lev_fill_2_1                 0.027546               0.052794
# temp_fl_start_12_0                            0.029697              -0.002502
# wind_dir_W_0                                  0.075839               0.058589
# problem_pwl-slab_lev_fill_2_1                -0.014425               0.004717
# temp_fl_start_18_0                            0.009217               0.010787
# problem_drift-slab_lev_fill_4_1              -0.007902               0.003847
# wind_chg_dir_E_0                             -0.030809              -0.016772
# wind_chg_dir_NE_0                             0.008601              -0.022407
# wind_dir_NE_0                                -0.030068              -0.026601
# problem_glide_lev_fill_3_1                   -0.003372              -0.001833
# wind_chg_start_6_0                           -0.012585              -0.004912
#
#                                  REAL_pwl-slab_lev_max  REAL_pwl-slab_lev_min  \
# wind_chg_start_12_0                           0.013943              -0.002157
# wind_dir_N_0                                 -0.021857              -0.004639
# precip_most_exposed_0                        -0.012580               0.006027
# wind_dir_SE_0                                 0.006114              -0.024440
# wind_chg_start_18_0                           0.017292              -0.003192
# problem_new-loose_lev_fill_4_1               -0.017839              -0.010825
# temp_fl_start_0_0                            -0.056780              -0.033833
# problem_new-loose_lev_fill_2_1               -0.017469              -0.013058
# wind_chg_dir_SE_0                             0.034089              -0.001132
# wind_chg_dir_SW_0                            -0.007237               0.021647
# wind_chg_dir_S_0                              0.034916               0.028978
# wind_chg_start_0_0                           -0.003838              -0.009296
# wind_dir_S_0                                 -0.005880               0.029621
# wind_dir_E_0                                 -0.018250              -0.027341
# wind_chg_dir_W_0                              0.009391              -0.000332
# wind_chg_dir_NW_0                             0.003596              -0.008425
# temp_fl_start_6_0                            -0.003561              -0.007360
# problem_new-slab_lev_fill_4_1                 0.017752               0.003558
# problem_wet-slab_lev_fill_2_1                 0.009636               0.023812
# wind_chg_dir_N_0                             -0.016162              -0.019570
# wind_dir_SW_0                                -0.009758               0.026290
# precip_0                                     -0.012323               0.005448
# problem_wet-loose_lev_fill_3_1               -0.015211              -0.009231
# problem_pwl-slab_lev_fill_3_1                 0.013127               0.017198
# wind_dir_NW_0                                 0.013472              -0.016491
# problem_new-slab_lev_fill_2_1                 0.030751               0.002224
# temp_fl_start_12_0                            0.086880               0.021726
# wind_dir_W_0                                  0.035768               0.037672
# problem_pwl-slab_lev_fill_2_1                 0.058791               0.080782
# temp_fl_start_18_0                           -0.026721              -0.019049
# problem_drift-slab_lev_fill_4_1               0.021483               0.034235
# wind_chg_dir_E_0                             -0.017107              -0.014638
# wind_chg_dir_NE_0                            -0.010790              -0.024363
# wind_dir_NE_0                                -0.034085              -0.029839
# problem_glide_lev_fill_3_1                   -0.005377              -0.003263
# wind_chg_start_6_0                           -0.002120               0.018886
#
#                                  REAL_wet-loose_lev_max  \
# wind_chg_start_12_0                           -0.049361
# wind_dir_N_0                                  -0.001773
# precip_most_exposed_0                          0.027446
# wind_dir_SE_0                                 -0.025241
# wind_chg_start_18_0                           -0.068337
# problem_new-loose_lev_fill_4_1                -0.011479
# temp_fl_start_0_0                             -0.029005
# problem_new-loose_lev_fill_2_1                -0.012688
# wind_chg_dir_SE_0                             -0.067680
# wind_chg_dir_SW_0                              0.002754
# wind_chg_dir_S_0                              -0.008488
# wind_chg_start_0_0                             0.003309
# wind_dir_S_0                                  -0.000306
# wind_dir_E_0                                  -0.005281
# wind_chg_dir_W_0                              -0.017557
# wind_chg_dir_NW_0                             -0.051376
# temp_fl_start_6_0                             -0.085137
# problem_new-slab_lev_fill_4_1                 -0.004572
# problem_wet-slab_lev_fill_2_1                 -0.036509
# wind_chg_dir_N_0                              -0.044433
# wind_dir_SW_0                                  0.034311
# precip_0                                       0.028280
# problem_wet-loose_lev_fill_3_1                 0.044770
# problem_pwl-slab_lev_fill_3_1                 -0.004572
# wind_dir_NW_0                                  0.017807
# problem_new-slab_lev_fill_2_1                 -0.002032
# temp_fl_start_12_0                             0.012579
# wind_dir_W_0                                  -0.007830
# problem_pwl-slab_lev_fill_2_1                 -0.031346
# temp_fl_start_18_0                             0.146522
# problem_drift-slab_lev_fill_4_1               -0.020463
# wind_chg_dir_E_0                              -0.040662
# wind_chg_dir_NE_0                             -0.040325
# wind_dir_NE_0                                 -0.015463
# problem_glide_lev_fill_3_1                     0.013785
# wind_chg_start_6_0                            -0.052672
#
#                                  REAL_wet-loose_lev_min  \
# wind_chg_start_12_0                           -0.042092
# wind_dir_N_0                                   0.008637
# precip_most_exposed_0                          0.059148
# wind_dir_SE_0                                 -0.041626
# wind_chg_start_18_0                           -0.059220
# problem_new-loose_lev_fill_4_1                -0.005221
# temp_fl_start_0_0                             -0.050190
# problem_new-loose_lev_fill_2_1                -0.012796
# wind_chg_dir_SE_0                             -0.045135
# wind_chg_dir_SW_0                             -0.009234
# wind_chg_dir_S_0                              -0.018541
# wind_chg_start_0_0                            -0.001272
# wind_dir_S_0                                   0.040244
# wind_dir_E_0                                  -0.021756
# wind_chg_dir_W_0                              -0.007593
# wind_chg_dir_NW_0                             -0.031820
# temp_fl_start_6_0                             -0.047169
# problem_new-slab_lev_fill_4_1                 -0.003197
# problem_wet-slab_lev_fill_2_1                 -0.011863
# wind_chg_dir_N_0                              -0.038621
# wind_dir_SW_0                                  0.003419
# precip_0                                       0.059131
# problem_wet-loose_lev_fill_3_1                 0.035169
# problem_pwl-slab_lev_fill_3_1                 -0.003197
# wind_dir_NW_0                                  0.035562
# problem_new-slab_lev_fill_2_1                  0.003056
# temp_fl_start_12_0                             0.014839
# wind_dir_W_0                                   0.018973
# problem_pwl-slab_lev_fill_2_1                 -0.019448
# temp_fl_start_18_0                             0.118423
# problem_drift-slab_lev_fill_4_1               -0.014309
# wind_chg_dir_E_0                              -0.027472
# wind_chg_dir_NE_0                             -0.036497
# wind_dir_NE_0                                 -0.013882
# problem_glide_lev_fill_3_1                     0.023594
# wind_chg_start_6_0                            -0.026788
#
#                                  REAL_wet-slab_lev_max  REAL_wet-slab_lev_min
# wind_chg_start_12_0                           0.018403              -0.002509
# wind_dir_N_0                                 -0.065298              -0.047325
# precip_most_exposed_0                        -0.002235               0.000042
# wind_dir_SE_0                                -0.083359              -0.073198
# wind_chg_start_18_0                           0.001175              -0.000380
# problem_new-loose_lev_fill_4_1               -0.009027              -0.006921
# temp_fl_start_0_0                            -0.032955              -0.027668
# problem_new-loose_lev_fill_2_1               -0.000378              -0.008349
# wind_chg_dir_SE_0                            -0.051668              -0.035185
# wind_chg_dir_SW_0                             0.113980               0.095963
# wind_chg_dir_S_0                              0.005350              -0.005636
# wind_chg_start_0_0                            0.008101              -0.000763
# wind_dir_S_0                                 -0.024095              -0.013485
# wind_dir_E_0                                 -0.053870              -0.046336
# wind_chg_dir_W_0                              0.044623               0.008954
# wind_chg_dir_NW_0                            -0.044189              -0.029719
# temp_fl_start_6_0                             0.005664               0.013618
# problem_new-slab_lev_fill_4_1                -0.002721              -0.002086
# problem_wet-slab_lev_fill_2_1                 0.192163               0.209407
# wind_chg_dir_N_0                             -0.037236              -0.030618
# wind_dir_SW_0                                 0.158883               0.148332
# precip_0                                     -0.004919              -0.002627
# problem_wet-loose_lev_fill_3_1               -0.007698              -0.005901
# problem_pwl-slab_lev_fill_3_1                -0.002721              -0.002086
# wind_dir_NW_0                                -0.070026              -0.053259
# problem_new-slab_lev_fill_2_1                 0.007419               0.013977
# temp_fl_start_12_0                           -0.001979              -0.024282
# wind_dir_W_0                                  0.098424               0.059942
# problem_pwl-slab_lev_fill_2_1                -0.020585              -0.015782
# temp_fl_start_18_0                            0.066150               0.071343
# problem_drift-slab_lev_fill_4_1              -0.012176              -0.009335
# wind_chg_dir_E_0                             -0.039607              -0.035602
# wind_chg_dir_NE_0                            -0.022046              -0.026481
# wind_dir_NE_0                                -0.048395              -0.041897
# problem_glide_lev_fill_3_1                   -0.002721              -0.002086
# wind_chg_start_6_0                           -0.003667               0.001158
#
# [36 rows x 55 columns]

# %%
drop_weak = correlations.loc[weak_correlations, :].index.values
correlations.drop(drop_weak, inplace=True)
correlations.shape
# Out:
# (129, 55)

# %%
fig, ax = plt.subplots(figsize=(20, 30))
sns.heatmap(correlations, xticklabels=correlations.columns, yticklabels=correlations.index, cmap='RdYlGn', ax=ax)
ax.set_title('Correlation Matrix for the Training Set Features')

plt.show()

# %% [markdown]
# **So according to our correlation analysis, there are about 129 features out of the original 291 that are useful in predicting one or more of our labels. We can save those below and compare them with what features our other analysis find useful.**

# %%
keep_columns_correlations = list(correlations.index)
keep_columns_correlations
# Out:
# ['problem_wet-slab_trig_1',
#  'problem_drift-slab_dsize_1',
#  'problem_wet-slab_prob_1',
#  'problem_drift-slab_cause_new-snow_1',
#  'problem_new-slab_lev_fill_1_1',
#  'problem_drift-slab_prob_1',
#  'problem_amount_1',
#  'problem_new-slab_trig_1',
#  'problem_drift-slab_aspect_SE_1',
#  'temp_min_0',
#  'problem_glide_aspect_SE_1',
#  'problem_drift-slab_lev_max_1',
#  'problem_pwl-slab_aspect_W_1',
#  'problem_pwl-slab_lev_max_1',
#  'problem_drift-slab_lev_min_1',
#  'problem_new-loose_trig_1',
#  'problem_glide_trig_1',
#  'problem_wet-slab_aspect_W_1',
#  'problem_pwl-slab_aspect_NE_1',
#  'problem_wet-loose_dsize_1',
#  'problem_wet-loose_prob_1',
#  'problem_glide_aspect_S_1',
#  'problem_new-loose_aspect_N_1',
#  'problem_wet-loose_aspect_E_1',
#  'problem_wet-loose_aspect_S_1',
#  'problem_wet-loose_aspect_SW_1',
#  'problem_pwl-slab_prob_1',
#  'problem_drift-slab_aspect_N_1',
#  'problem_new-loose_aspect_SW_1',
#  'problem_wet-slab_lev_max_1',
#  'problem_wet-slab_lev_fill_1_1',
#  'problem_glide_dsize_1',
#  'problem_new-loose_aspect_S_1',
#  'problem_new-slab_aspect_NW_1',
#  'problem_wet-loose_lev_min_1',
#  'problem_new-loose_lev_max_1',
#  'problem_drift-slab_1',
#  'problem_wet-slab_aspect_E_1',
#  'problem_wet-slab_lev_min_1',
#  'problem_pwl-slab_lev_min_1',
#  'problem_new-slab_aspect_E_1',
#  'problem_pwl-slab_aspect_S_1',
#  'problem_pwl-slab_lev_fill_4_1',
#  'problem_wet-slab_aspect_SW_1',
#  'problem_glide_aspect_NW_1',
#  'problem_glide_lev_max_1',
#  'problem_wet-loose_1',
#  'problem_drift-slab_aspect_W_1',
#  'problem_wet-loose_aspect_NW_1',
#  'problem_wet-loose_aspect_SE_1',
#  'problem_new-slab_lev_max_1',
#  'problem_pwl-slab_aspect_NW_1',
#  'problem_glide_aspect_W_1',
#  'problem_wet-slab_aspect_S_1',
#  'problem_pwl-slab_dsize_1',
#  'problem_wet-loose_lev_fill_2_1',
#  'emergency_warning_1',
#  'problem_drift-slab_lev_fill_1_1',
#  'problem_wet-loose_dist_1',
#  'problem_new-slab_dsize_1',
#  'problem_drift-slab_aspect_NE_1',
#  'problem_glide_lev_fill_4_1',
#  'problem_drift-slab_dist_1',
#  'problem_wet-slab_aspect_NE_1',
#  'problem_drift-slab_aspect_S_1',
#  'problem_pwl-slab_dist_1',
#  'problem_drift-slab_aspect_NW_1',
#  'problem_wet-loose_lev_fill_1_1',
#  'problem_new-slab_1',
#  'problem_glide_1',
#  'problem_new-loose_dsize_1',
#  'problem_new-loose_aspect_NW_1',
#  'problem_wet-loose_lev_fill_4_1',
#  'problem_new-loose_1',
#  'problem_pwl-slab_aspect_SW_1',
#  'wind_speed_0',
#  'problem_wet-loose_aspect_N_1',
#  'problem_wet-loose_aspect_W_1',
#  'problem_glide_dist_1',
#  'problem_drift-slab_aspect_SW_1',
#  'problem_new-slab_aspect_SW_1',
#  'problem_new-loose_lev_min_1',
#  'problem_wet-slab_aspect_N_1',
#  'problem_new-slab_aspect_NE_1',
#  'problem_drift-slab_trig_1',
#  'temp_lev_0',
#  'problem_pwl-slab_aspect_E_1',
#  'problem_wet-loose_aspect_NE_1',
#  'problem_new-loose_aspect_SE_1',
#  'problem_new-slab_lev_min_1',
#  'problem_new-slab_prob_1',
#  'problem_wet-slab_aspect_SE_1',
#  'problem_wet-slab_dsize_1',
#  'problem_wet-slab_dist_1',
#  'problem_glide_prob_1',
#  'problem_wet-slab_aspect_NW_1',
#  'problem_wet-loose_lev_max_1',
#  'problem_new-loose_dist_1',
#  'problem_new-slab_aspect_S_1',
#  'problem_pwl-slab_aspect_N_1',
#  'problem_pwl-slab_aspect_SE_1',
#  'problem_glide_lev_min_1',
#  'temp_max_0',
#  'problem_wet-loose_trig_1',
#  'problem_new-loose_aspect_W_1',
#  'problem_glide_aspect_E_1',
#  'problem_new-slab_cause_new-snow_1',
#  'problem_new-slab_aspect_SE_1',
#  'problem_pwl-slab_trig_1',
#  'temp_freeze_lev_0',
#  'problem_glide_lev_fill_1_1',
#  'problem_glide_lev_fill_2_1',
#  'problem_glide_aspect_SW_1',
#  'problem_glide_aspect_NE_1',
#  'problem_glide_aspect_N_1',
#  'problem_wet-slab_1',
#  'problem_pwl-slab_1',
#  'problem_wet-slab_lev_fill_4_1',
#  'problem_new-loose_aspect_NE_1',
#  'problem_pwl-slab_lev_fill_1_1',
#  'problem_new-loose_aspect_E_1',
#  'problem_new-slab_aspect_W_1',
#  'danger_level_1',
#  'problem_new-loose_lev_fill_1_1',
#  'problem_drift-slab_aspect_E_1',
#  'problem_new-slab_aspect_N_1',
#  'wind_change_speed_0',
#  'problem_new-slab_dist_1',
#  'problem_new-loose_prob_1']

# %% [markdown]
# # Feature importances
#
# Next, we can look at which features a Random Forest model thinks are important. To do this, we can use the whole dataset as a predictor for the labels.

# %% [markdown]
# This will look something like:
# ```python
# X, y = labeled_data.data, labels
#
# num_iter = 10
# random = 0   #makes sure the models and grid search object give the same results every time
#
# #instantiate models here
# forest = RandomForestRegressor(random_state=random)
#
# #define parameters dictionaries here
# ensemble_params = {'n_estimators': [1, 2, 4, 8, 16, 32, 64, 100, 200],
#              'max_depth': [1, 2, 4, 6, 8, 10, 20, 30, None],  #higher values often lead to overfitting
#              'max_features': ['auto', 'sqrt', 'log2'],
#              'min_samples_leaf': [1, 2, 4],
#              'min_samples_split': [2, 5, 10],
#             'bootstrap': [True, False]
#             }
#
# #create our random search cv objects
# forest_search = RandomizedSearchCV(estimator=forest,
#                         param_distributions=ensemble_params,
#                         n_iter=num_iter,         #number of parameter settings sampled
#                         scoring='neg_root_mean_squared_error',
#                         n_jobs=-1,         #use all processors available
#                         cv=5,
#                         verbose=2,         #print results during tuning
#                         random_state=random
# )
#
# #now fit the search objects and return them
# forest_model = forest_search.fit(X, y)
#
#
# print('Best RandomForest model:')
# print(forest_model.best_params_, '\n')
# ```

# %% [markdown]
# ```python
# def plot_importances(df, labels, rf):
#     """
#     Input a dataframe as well as trained RandomForest model, plot feature importances.
#
#     """
#     columns = df.columns #all columns except the target column
#     importances_rf = rf.best_estimator_.feature_importances_
#
#     #take the top ten feature importances
#     idx_rf = np.argsort(importances_rf)
#     #idx_rf = np.argsort(importances_rf)[-10:]
#
#     fig, ax = plt.subplots(figsize=(12, 7))
#     #random forest and xgboost feature importances on the same plot
#     ax.set_title('Feature Importances')
#     ax.barh(range(len(idx_rf)), importances_rf[idx_rf], color='tab:blue', align='center', alpha=0.5, label='RF')
#
#     ax.set_yticks(range(len(idx_rf)))
#     ax.set_yticklabels([columns[i] for i in idx_rf], fontsize=10)
#     ax.set_xlabel('Relative Importance')
#
#     ax.legend()
#     plt.show()
#
# # need to make sure this is using the "best" model by default
# plot_importances(labeled_data.data, labels, forest_model)
#
# ```

# %% [markdown]
# # PCA
# - https://scentellegher.github.io/machine-learning/2020/01/27/pca-loadings-sklearn.html
# - https://stackoverflow.com/questions/22984335/recovering-features-names-of-explained-variance-ratio-in-pca-with-sklearn
#
# Look here for previous work that I've done as a guide: https://github.com/Jakidxav/udacity_ml_pytorch/blob/master/customer_segments_clustering/arvato_pca_clustering.ipynb
